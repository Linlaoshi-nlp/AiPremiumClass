# %%
import os
from transformers import (
    AutoModelForTokenClassification,
    AutoTokenizer,
    DataCollatorForTokenClassification,
)
from transformers import TrainingArguments, Trainer
import evaluate
from datasets import DownloadConfig, load_dataset
import numpy as np

# %%
# 设置HF镜像端点（国内加速）
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'

# 同时配置PyPI镜像（安装依赖更稳定）
os.system('pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple')

# 启用断点续传 + 重试机制
download_config = DownloadConfig(
    resume_download=True,    # 断点续传
    max_retries=1000,         # 最大重试次数
    num_proc=1               # 避免并行下载导致资源竞争
)
ds = load_dataset('msra_ner', trust_remote_code=True, download_config=download_config)
# Out:
# ...
# ---------------------------------------------------------------------------
# ContentLengthError                        Traceback (most recent call last)
# File g:\Hmsoft\Anaconda\package\envs\py312\Lib\site-packages\aiohttp\client_proto.py:144, in ResponseHandler.connection_lost(self, exc)
#     143 try:
# --> 144     uncompleted = self._parser.feed_eof()
#     145 except Exception as underlying_exc:
#
# File g:\Hmsoft\Anaconda\package\envs\py312\Lib\site-packages\aiohttp\_http_parser.pyx:511, in aiohttp._http_parser.HttpParser.feed_eof()
#
# ContentLengthError: 400, message:
#   Not enough data to satisfy content length header.
#
# The above exception was the direct cause of the following exception:
#
# ClientPayloadError                        Traceback (most recent call last)
# Cell In[33], line 13
#       7 # 启用断点续传 + 重试机制
#       8 download_config = DownloadConfig(
#       9     resume_download=True,    # 断点续传
#      10     max_retries=1000,         # 最大重试次数
# ...
